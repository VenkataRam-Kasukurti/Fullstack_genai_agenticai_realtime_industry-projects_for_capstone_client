# %% [markdown]
# # DICTIONARY

# %%
d = {1: 'one', 2:'two', 3:'three', 4:'four'}

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
d.values()
# Out:
# dict_values(['one', 'two', 'three', 'four'])

# %%
d[1]
# Out:
# 'one'

# %%
d[5] = 'five'

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}

# %%
d[1+2j] = 2.3

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', (1+2j): 2.3}

# %%
d.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'three'), (4, 'four'), (5, 'five'), ((1+2j), 2.3)])

# %%
keys = {'a', 'b', 'c', 'd'}
mydict3 = dict.fromkeys(keys)
mydict3
# Out:
# {'b': None, 'a': None, 'd': None, 'c': None}

# %%
keys = {'a', 'b', 'c', 'd'}
value = [10, 20, 30, 40]
mydict3 = dict.fromkeys(keys, value)
mydict3
# Out:
# {'b': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40],
#  'd': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40]}

# %%
value.append(50)
mydict3
# Out:
# {'b': [10, 20, 30, 40, 50],
#  'a': [10, 20, 30, 40, 50],
#  'd': [10, 20, 30, 40, 50],
#  'c': [10, 20, 30, 40, 50]}

# %%
mydict3['a']
# Out:
# [10, 20, 30, 40, 50]

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', (1+2j): 2.3}

# %%
d.get(4)
# Out:
# 'four'

# %%
d[5]
# Out:
# 'five'

# %% [markdown]
# # IF STATEMENT

# %%
x = 4
r = x%2
if r == 0:
    print('Even number')

# %%
x = 5
r = x%2
if r == 0:
    print('Even number')
else:
    print('Odd number')

# %%
x = 4
r = x%2
if r == 0:
    print('Even number')
    if x>0:
        print('Greater Number')
else:
    print('Odd number')

# %%
x = 5

if x == 1:
    print('one')

elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:

    print('four')

else:
    print('Number not found')
