# %% [markdown]
# # NUMBER(INTEGER)

# %%
5
# Out:
# 5

# %%
5 + 6 # operator
# Out:
# 11

# %%
10 + 5
# Out:
# 15

# %%
10 * 5
# Out:
# 50

# %%
10 / 5 # decimal (float devision)
# Out:
# 2.0

# %%
10 // 5 # decimal (int devision)
# Out:
# 2

# %%
3 ** 2
# Out:
# 9

# %%
10 % 5
# Out:
# 0

# %% [markdown]
# # TEXT (STRING)

# %% [raw]
# IN PYTHON STRING ALWAYS ''|""|''''''

# %%
'HELLO'
# Out:
# 'HELLO'

# %%
"WELCOME TO THE PYTHON PROGRAMMING"
# Out:
# 'WELCOME TO THE PYTHON PROGRAMMING'

# %%
'''WELCOME TO THE PYTHON PROGRAMMING'''
# Out:
# 'WELCOME TO THE PYTHON PROGRAMMING'

# %% [raw]
# ERROR TYPES ----> COMPILE TIME ERROE,

# %% [raw]
# IN PYTHON PROGRAMMING LANGUAGE ALSO HAS NAME & NAME IS CALLED VARIABLE (VARIABLE == OBJECT)

# %% [markdown]
# # PYTHON VARIABLE DECLARATION

# %%
V = 5 # VARIABLE = VALUE
V
# Out:
# 5

# %% [raw]
# SYNTAX OF THE VARIABLE IS | VARIABLE = VALUE ---- VALUE ALSO CALLED AS DATATYPES(INT, FLOAT,BOOL, COMPLEX, STRING)

# %%
id(V) # id is the address of the variable which is stored
# Out:
# 140710383494184

# %% [raw]
# VARIABLES RULES:
# 1.variable can not start with digit but it can end with digit.
# 2.variables are case sensitive.
# 3.variables does not allow special characters except underscore(_).
# 4.variriable can not be key word or reserved word(print,start,etc.,).

# %%
1v = 20
1v
# Out:
#   Cell In[24], line 1
#     1v = 20
#     ^
# SyntaxError: invalid decimal literal

# %%
v1 = 20
v1
# Out:
# 20

# %%
nit = 27
nit
# Out:
# 27

# %%
nit@ = 50
nit@
# Out:
#   Cell In[27], line 1
#     nit@ = 50
#          ^
# SyntaxError: invalid syntax

# %%
nit_ = 50
nit_
# Out:
# 50

# %%
_nit = 51
_nit
# Out:
# 51

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [raw]
# Ressigning the value

# %%
x = 10
x
# Out:
# 10

# %%
x = 20
x
# Out:
# 20

# %% [raw]
# PYTHON EVERY FUNCTION MUST END WITH():

# %% [raw]
# car() -- function without argument or function without parameter
# german_car(audi, bmw, volks)  --- function with 3 argument|fun eith 3 argument
# asian-cars(maruti, toy, honda, tata, mahindra)  -- function with 5 argumnets
#
#
# chatgpt(3 billion) has build with that why it is called LLM
#
# argument == parameter
#
# differrence between variable vs function?
#
# variable doesnot ()
#
# function has argument()

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
# Out:
# 15
# 5
# 50
