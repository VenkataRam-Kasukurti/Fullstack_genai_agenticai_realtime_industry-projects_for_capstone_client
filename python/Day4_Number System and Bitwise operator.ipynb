# %% [markdown]
# # Arthematic operators

# %%
x1, y1 = 10, 5

# %%
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1 * y1
# Out:
# 50

# %%
x1 / y1 # float division
# Out:
# 2.0

# %%
x1 // y1 # int division
# Out:
# 2

# %%
x1 % y1
# Out:
# 0

# %%
x1 ** y1
# Out:
# 100000

# %%
3 ** 2
# Out:
# 9

# %%
x2 = 3
y2 = 3

x2 ** y2
# Out:
# 27

# %% [markdown]
# # Assignment operators

# %%
x = 2

# %%
x = x + 2 # if you want to increment by 2

# %%
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 12

# %%
x += 2
x
# Out:
# 16

# %%
x *= 2
x
# Out:
# 64

# %%
x -= 2
x
# Out:
# 60

# %%
x /= 2
x
# Out:
# 15.0

# %%
x //= 2
x
# Out:
# 3.0

# %%
a, b = 5,6 # you can assigned variable in one line as well
print(a)
print(b)
# Out:
# 5
# 6

# %%
a = 5
b = 6
print(a)
print(b)
# Out:
# 5
# 6

# %% [markdown]
# # unary operator

# %%
n = 7 # negattion
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %% [markdown]
# # Relational operator

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b  = 5

# %%
a == b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
a > b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# False

# %%
b = 7

# %%
a != b
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a > 8 and b < 2
# Out:
# False

# %%
a > 8 or b < 2
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
x = not x
x
# Out:
# False

# %%
x
# Out:
# False

# %%
not x
# Out:
# True

# %% [markdown]
# # Number system conversion

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin (30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
int(0b11110)
# Out:
# 30

# %%
0o31
# Out:
# 25

# %%
0b1101
# Out:
# 13

# %%
int(0b1101)
# Out:
# 13

# %%
bin(7)
# Out:
# '0b111'

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
hex(16)
# Out:
# '0x10'

# %%
0xa
# Out:
# 10

# %%
0xb
# Out:
# 11

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(25)
# Out:
# '0x19'

# %%
0x15
# Out:
# 21

# %% [markdown]
# # Swapp 2 -variables in python

# %%
a = 5
b = 6

# %%
a = b
b = a

# %%
print(a)
print(b)
# Out:
# 6
# 6

# %%
a1 = 7
b1 = 8

# %%
temp = a1
a1 = b1
b1 = temp

# %%
print(a1)
print(b1)
# Out:
# 8
# 7

# %%
a2 = 5
b2 = 6

# %%
a2 = a2 + b2
b2 = a2 - b2
a2 = a2 - b2

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
0b110
# Out:
# 6

# %%
0b101
# Out:
# 5

# %%
print(0b110)
print(0b101)
# Out:
# 6
# 5

# %%
print(0b101)
print(0b110)
# Out:
# 5
# 6

# %%
print(bin(11))
# Out:
# 0b1011

# %%
print(0b1011)
# Out:
# 11

# %% [markdown]
# # XOR

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
a2 = a2 ^ b2
b2 = a2 ^ b2
a2 = a2 ^ b2

# %%
print(a2)
print(b2)
# Out:
# 5
# 6

# %%
a2, b2 = b2, a2

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %% [markdown]
# # BITWISE OPERATOR

# %%
print(bin(12))
print(bin(13))
# Out:
# 0b1100
# 0b1101

# %%
# complement
~ 12
# Out:
# -13

# %%
~ 46
# Out:
# -47

# %%
~ 54
# Out:
# -55

# %%
~ 10
# Out:
# -11

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
1 & 0
# Out:
# 0

# %%
1 | 0
# Out:
# 1

# %%
bin (13)
# Out:
# '0b1101'

# %%
print(bin(35))
print(bin(40))
# Out:
# 0b100011
# 0b101000

# %%
35 & 40
# Out:
# 32

# %%
35 | 40
# Out:
# 43

# %%
12 ^ 13
# Out:
# 1

# %%
print(bin(25))
print(bin(30))
# Out:
# 0b11001
# 0b11110

# %%
25^ 30
# Out:
# 7

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10 << 2
# Out:
# 40

# %%
bin(10)
# Out:
# '0b1010'

# %%
10<<1
# Out:
# 20

# %%
10<<2
# Out:
# 40

# %%
bin(20)
# Out:
# '0b10100'

# %%
20<<4
# Out:
# 320
