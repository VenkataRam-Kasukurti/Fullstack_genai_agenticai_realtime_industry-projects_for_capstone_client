# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %% [markdown]
# # Keywords

# %% [raw]
# keywords are the reserved words in python and can't be used as an identifiers

# %%
print (keyword.kwlist)# list all python keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers

# %% [raw]
# An identifier is a name given to entities like class, function, variables etc. it helps to differenciate one entity from another

# %%
1var =10 # Identifier can't start with a digit
# Out:
#   Cell In[4], line 1
#     1var =10 # Identifier can't start with a digit
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@ = 35 # Identifier can't use special symbols
# Out:
#   Cell In[5], line 1
#     val2@ = 35 # Identifier can't use special symbols
#           ^
# SyntaxError: invalid syntax

# %%
import = 125 # Import can not be used as a identifiers
# Out:
#   Cell In[6], line 1
#     import = 125 # Import can not be used as a identifiers
#            ^
# SyntaxError: invalid syntax

# %%
"""
correct way of identifiers
(Identifiers can be a combination of letters in lowercase(a to z) or uppercase
"""
val2 = 10

# %%
val_ = 99
val_
# Out:
# 99

# %% [markdown]
# # Comments in python

# %% [raw]
# Comments can be used to explain the code for more readability

# %%
# Single line comment
val1 = 10

# %%
# Multiple 
# line
# Comment
val1 = 10

# %%
'''
Multiple
line
comment
'''
val1 = 10

# %%
"""
Multiple
line
comment
"""
val1 = 10

# %% [markdown]
# # Statement

# %% [raw]
# Instructions that a python interpreter can execute.

# %%
p = 20 # create an intiger object with value 20 and assign the variable p to p
q = 20 # create new reference q which will point to value 20.
r = q  # variable r will also point to the same location where p & q are pointing 
p, type(p), hex(id(p))
# Out:
# (20, int, '0x7ffa0162a608')

# %%
q, type(q), hex(id(q))
# Out:
# (20, int, '0x7ffa0162a608')

# %%
r, type(r), hex(id(r))
# Out:
# (20, int, '0x7ffa0162a608')

# %%
p = 20
p = p+ 10 # variable overwriting
p
# Out:
# 30

# %% [markdown]
# # Variable Assigment

# %%
intvar = 10 # Intiger variable
floatvar = 2.57 # Float Variable
strvar = "Python Language" # String Variable

print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %% [markdown]
# # Multiple Assignments

# %%
intvar , floatvar, strvar = 10, 2.57, "Python Language" # using commas to seprate 
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %% [markdown]
# # Data Types

# %% [raw]
# Numeric

# %%
val1 = 10 # Integer data type 
print(val1) 
print(type(val1)) # type of object 
print(sys.getsizeof(val1)) # size of integer object in bytes 
print(val1, " is Integer?", isinstance(val1, int)) # val1 is an instance of int
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2 = 92.78 # Float data type 
print(val2) 
print(type(val2)) # type of object 
print(sys.getsizeof(val2)) # size of float object in bytes 
print(val2, " is float?", isinstance(val2, float)) # Val2 is an instance of floa
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
val3 = 25 + 10j # Complex data type 
print(val3) 
print(type(val3)) # type of object 
print(sys.getsizeof(val3)) # size of float object in bytes 
print(val3, " is complex?", isinstance(val3, complex)) # val3 is an instance
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %%
sys.getsizeof(int()) # size of integer object in bytes
# Out:
# 28

# %%
sys.getsizeof(float()) # size of float object in bytes
# Out:
# 24

# %%
sys.getsizeof(complex()) # size of complex object in bytes
# Out:
# 32

# %% [markdown]
# # Boolean

# %% [raw]
# Boolean data type can have only two possible values true or false

# %%
bool1 = True

# %%
bool2 = False

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
print(type(bool2))
# Out:
# <class 'bool'>

# %%
isinstance(bool1,bool)
# Out:
# True

# %%
isinstance(bool2,bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # String

# %% [raw]
# String Creation

# %%
str1 = "Hello Python"
str1
# Out:
# 'Hello Python'

# %%
str1 = "Hello Python" # Defing string with Double quotes
print(str1)
# Out:
# Hello Python

# %%
mystr = 'Hello World' # Defing string with Single quotes
print(mystr)
# Out:
# Hello World

# %%
# Defing string with triple quotes
mystr = '''Hello       
           World'''
print(mystr)
# Out:
# Hello
#            World

# %%
# Defing string with triple quotes
mystr = """Hello       
           World"""
print(mystr)
# Out:
# Hello
#            World

# %%
mystr = ('Happy '
         'Monday '
         'Everyone')
print(mystr)
# Out:
# Happy Monday Everyone

# %%
mystr2 = 'Woohoo ' 
mystr2 = mystr2*5 
mystr2
# Out:
# 'Woohoo Woohoo Woohoo Woohoo Woohoo '

# %%
len(mystr2) # Length of string
# Out:
# 35

# %% [raw]
# String Indexing

# %%
str1
# Out:
# 'Hello Python'

# %%
str1[0] # First character in string "str1"
# Out:
# 'H'

# %%
str1[len(str1)-1] # Last character in string using len function
# Out:
# 'n'

# %%
str1[-1] # Last character in string
# Out:
# 'n'

# %%
str1[6] #Fetch 7th element of the string
# Out:
# 'P'

# %%
str1[5]
# Out:
# ' '

# %% [raw]
# String Slicing

# %%
str1[0:5] # String slicing - Fetch all characters from 0 to 5 index location exc
# Out:
# 'Hello'

# %%
str1[6:12] # String slicing - Retreive all characters between 6 - 12 index loc
# Out:
# 'Python'

# %%
str1[-4:] # Retreive last four characters of the string
# Out:
# 'thon'

# %%
str1[-6:] # Retreive last six characters of the string
# Out:
# 'Python'

# %%
str1[:4] # Retreive first four characters of the string
# Out:
# 'Hell'

# %%
str1[:6] # Retreive first six characters of the string
# Out:
# 'Hello '

# %% [raw]
# Updatd & Delete String

# %%
str1
# Out:
# 'Hello Python'

# %%
#Strings are immutable which means elements of a string cannot be changed once  
str1[0:5] = 'HOLAA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 #Strings are immutable which means elements of a string cannot be changed once
# ----> 2 str1[0:5] = 'HOLAA'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 # Delete a string 
print(srt1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 del str1 # Delete a string
# ----> 2 print(srt1)
#
# NameError: name 'srt1' is not defined

# %% [raw]
# String concatenation

# %%
# String concatenation 
s1 = "Hello" 
s2 = "Asif" 
s3 = s1 + s2 
print(s3)
# Out:
# HelloAsif
