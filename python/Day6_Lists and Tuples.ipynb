# %%
l= [10,25,30,60,50,10]
l1=[10, 2.3, 'int', (1+2j)]

# %%
l
# Out:
# [10, 25, 30, 60, 50, 10]

# %%
l1
# Out:
# [10, 2.3, 'int', (1+2j)]

# %%
l.extend(l1)

# %%
l
# Out:
# [10, 25, 30, 60, 50, 10, 10, 2.3, 'int', (1+2j)]

# %%
l.index(50)
# Out:
# 4

# %%
l.index(10)
# Out:
# 0

# %%
l
# Out:
# [10, 25, 30, 60, 50, 10, 10, 2.3, 'int', (1+2j)]

# %%
l.insert(2, 44)
l
# Out:
# [10, 25, 44, 44, 44, 30, 60, 50, 10, 10, 2.3, 'int', (1+2j)]

# %%
l.pop()
l
# Out:
# [10, 25, 44, 44, 44, 30, 60, 50, 10, 10, 2.3, 'int']

# %%
l.pop()
# Out:
# 'int'

# %%
l.pop(6)
# Out:
# 60

# %%
l
# Out:
# [10, 25, 44, 44, 44, 30, 50, 10, 10, 2.3]

# %%
l.remove(44)
l
# Out:
# [10, 25, 44, 30, 50, 10, 10, 2.3]

# %%
l.reverse()
l
# Out:
# [2.3, 10, 10, 50, 30, 44, 25, 10]

# %%
l1
# Out:
# [10, 2.3, 'int', (1+2j)]

# %%
l
# Out:
# [2.3, 10, 10, 50, 30, 44, 25, 10]

# %%
l.sort()

# %%
l
# Out:
# [2.3, 10, 10, 10, 25, 30, 44, 50]

# %%
l.sort(reverse = True)
l
# Out:
# [50, 44, 30, 25, 10, 10, 10, 2.3]

# %%
l1
# Out:
# [10, 2.3, 'int', (1+2j)]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l
# Out:
# [50, 44, 30, 25, 10, 10, 10, 2.3]

# %%
l.append([2,5,6,7,9])
l
# Out:
# [50, 44, 30, 25, 10, 10, 10, 2.3, [2, 5, 6, 7, 9]]

# %%
for i in l1:
    print(i)
# Out:
# 10
# 2.3
# int
# (1+2j)

# %%
for i in enumerate (l1):
    print(i)
# Out:
# (0, 10)
# (1, 2.3)
# (2, 'int')
# (3, (1+2j))

# %% [markdown]
# # Tuple

# %%
t = 10,20,30
t
# Out:
# (10, 20, 30)

# %%
type(t)
# Out:
# tuple

# %%
t.count(10)
# Out:
# 1

# %%
t.index(10)
# Out:
# 0

# %%
t[1]
# Out:
# 20
