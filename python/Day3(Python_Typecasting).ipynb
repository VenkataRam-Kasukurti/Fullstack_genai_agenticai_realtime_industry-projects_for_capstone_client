# %%
s1 = 'VenkataRam'

# %%
s1[:]
# Out:
# 'VenkataRam'

# %%
s1[7:9]
# Out:
# 'Ra'

# %%
s1[:7]
# Out:
# 'Venkata'

# %%
s1
# Out:
# 'VenkataRam'

# %%
s1[7:]
# Out:
# 'Ram'

# %% [markdown]
# #Advance Slicing

# %%
s1
# Out:
# 'VenkataRam'

# %%
s1[::3]      # forward indexing  step count-----> Begining:End:Step
# Out:
# 'Vkam'

# %%
s1[::-2]      # backward indexing  step count-----> Begining:End:Step
# Out:
# 'mRtke'

# %%
s2 = 'welcometonit'

# %%
s2[0:10:5]
# Out:
# 'wm'

# %%
s2[::-1]     # Reverse slicing
# Out:
# 'tinotemoclew'

# %%
s2
# Out:
# 'welcometonit'

# %%
s2 [::-5]
# Out:
# 'tee'

# %% [markdown]
# # python Type casting
# - convert from all other datatype to integer

# %%
# convert or type cast from one datatype to another
int(10.3)
# Out:
# 10

# %%
int(True)
# Out:
# 1

# %%
True + True +True
# Out:
# 3

# %%
int(False)
# Out:
# 0

# %%
int(10.3,12.5) # in type casting user can pass only one arguments
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 int(10.3,12.5) # in type casting user can pass only one arguments
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('ram')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 int('ram')
#
# ValueError: invalid literal for int() with base 10: 'ram'

# %%
float(34)
# Out:
# 34.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('10')
# Out:
# 10.0

# %%
float("ram")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 float("ram")
#
# ValueError: could not convert string to float: 'ram'

# %%
bool(10)
# Out:
# True

# %%
bool(10.45)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
bool(0.4)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool("10")
# Out:
# True

# %%
bool("ten")
# Out:
# True

# %% [markdown]
# # all other data type to complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(12.4)
# Out:
# (12.4+0j)

# %%
complex(12.45,13.45)
# Out:
# (12.45+13.45j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex("10")
# Out:
# (10+0j)

# %%
str(10)
# Out:
# '10'

# %%
str(10.54)
# Out:
# '10.54'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(10+2j)
# Out:
# '(10+2j)'
