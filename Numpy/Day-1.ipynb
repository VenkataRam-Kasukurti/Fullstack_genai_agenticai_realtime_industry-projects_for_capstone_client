# %%
import numpy as np

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.ones(5, dtype=int)
# Out:
# array([1, 1, 1, 1, 1])

# %%
np.ones([2,3])
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.ones([2,3], dtype=int)
# Out:
# array([[1, 1, 1],
#        [1, 1, 1]])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.random.rand(3)
# Out:
# array([0.43256162, 0.94707495, 0.79363523])

# %%
np.random.rand(3,4)
# Out:
# array([[0.1484467 , 0.60318495, 0.93554484, 0.22140652],
#        [0.4144978 , 0.83200946, 0.99057895, 0.72711006],
#        [0.32933046, 0.92195668, 0.25100014, 0.1320805 ]])

# %%
np.random.randint(3)
# Out:
# 2

# %%
np.random.randint(5,10)
# Out:
# 6

# %%
np.random.randint(2,10,4)
# Out:
# array([3, 3, 7, 6], dtype=int32)

# %%
arr1 = np.random.randint(1,9,(4,5))
arr1
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[0]
# Out:
# array([8, 5, 2, 8, 1], dtype=int32)

# %%
arr1[3]
# Out:
# array([8, 3, 1, 3, 5], dtype=int32)

# %%
arr1.shape
# Out:
# (4, 5)

# %%
arr1
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[1,4]
# Out:
# np.int32(2)

# %%
print(arr1[1,4])
# Out:
# 2

# %%
arr1[-3, 3]
# Out:
# np.int32(6)

# %%
arr1
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[::-3]
# Out:
# array([[8, 3, 1, 3, 5],
#        [8, 5, 2, 8, 1]], dtype=int32)

# %%
arr1[:4]
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[:40]
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[:10]
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[2:]
# Out:
# array([[7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr1[10:]
# Out:
# array([], shape=(0, 5), dtype=int32)

# %%
arr1[:,0]
# Out:
# array([8, 6, 7, 8], dtype=int32)

# %%
arr1[:,4]
# Out:
# array([1, 2, 3, 5], dtype=int32)

# %%
arr1[:, -1]
# Out:
# array([1, 2, 3, 5], dtype=int32)

# %%
arr1[1:3, 1:3]
# Out:
# array([[5, 8],
#        [6, 3]], dtype=int32)

# %%
arr1
# Out:
# array([[8, 5, 2, 8, 1],
#        [6, 5, 8, 6, 2],
#        [7, 6, 3, 4, 3],
#        [8, 3, 1, 3, 5]], dtype=int32)

# %%
arr = [0,1,2,3,4,5]
arr
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
arr.reshape(1,6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 arr.reshape(1,6)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
arr
# Out:
# [0, 1, 2, 3, 4, 5]
